# %% [markdown]
# # Content Based Recommandation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
credits=pd.read_csv('tmdb_5000_credits.csv')
movie=pd.read_csv('tmdb_5000_movies.csv')

# %%
credits.head(1)
# Out:
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movie.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
#merge the both dataset based on the common feature
movies=movie.merge(credits,on="title")

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'movie_id', 'cast', 'crew'],
#       dtype='object')

# %%
#then select the columns based on the our domain knowledge to recommend the movies
#genres
#keywords
#overview
#title
#id
#cast
#crew

movies = movies[["genres","id","keywords","overview","title","cast","crew"]]

# %%
movies.head(1)
# Out:
#                                               genres     id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                             overview   title  \
# 0  In the 22nd century, a paraplegic Marine is di...  Avatar
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies.isnull().sum()
# Out:
# genres      0
# id          0
# keywords    0
# overview    3
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# genres      0
# id          0
# keywords    0
# overview    0
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.head(1)
# Out:
#                                               genres     id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                             overview   title  \
# 0  In the 22nd century, a paraplegic Marine is di...  Avatar
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
#literal eval:as the name suggest it evaluate the string to give give the correct datatype value
import ast
ast.literal_eval("[5,8,9]")
# Out:
# [5, 8, 9]

# %%
#now i combine the geners,keywards,cast and crew into single feature to make efficient 
def get_genres(a):
    l=[]
    for i in ast.literal_eval(a):
        l.append(i['name'])
    return l

# %%
genres=movies["genres"].apply(get_genres)

# %%
movies["genres"]=genres

# %%
movies
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4804                      [Action, Crime, Thriller]    9367
# 4805                              [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TV Movie]  231617
# 4807                                             []  126186
# 4808                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...
# ...

# %%
key=movies["keywords"].apply(get_genres)

# %%
movies["keywords"]=key

# %%
movies
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4804                      [Action, Crime, Thriller]    9367
# 4805                              [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TV Movie]  231617
# 4807                                             []  126186
# 4808                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [culture clash, future, space war, space colon...
# 1     [ocean, drug abuse, exotic island, east india ...
# 2     [spy, based on novel, secret agent, sequel, mi...
# ...

# %%
def get_cast(z):
    counter=1
    l=[]
    for i in ast.literal_eval(z):
        if(counter<=3):
            l.append(i['name'])
            counter=counter+1
        else:
            break
    return l

# %%
cast=movies["cast"].apply(get_cast)

# %%
movies["cast"]=cast

# %%
movies
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4804                      [Action, Crime, Thriller]    9367
# 4805                              [Comedy, Romance]   72766
# 4806             [Comedy, Drama, Romance, TV Movie]  231617
# 4807                                             []  126186
# 4808                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [culture clash, future, space war, space colon...
# 1     [ocean, drug abuse, exotic island, east india ...
# 2     [spy, based on novel, secret agent, sequel, mi...
# ...

# %%
ast.literal_eval(movies.crew[0])
# Out:
# [{'credit_id': '52fe48009251416c750aca23',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1721,
#   'job': 'Editor',
#   'name': 'Stephen E. Rivkin'},
#  {'credit_id': '539c47ecc3a36810e3001f87',
#   'department': 'Art',
#   'gender': 2,
#   'id': 496,
#   'job': 'Production Design',
#   'name': 'Rick Carter'},
#  {'credit_id': '54491c89c3a3680fb4001cf7',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Sound Designer',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '54491cb70e0a267480001bd0',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Supervising Sound Editor',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '539c4a4cc3a36810c9002101',
#   'department': 'Production',
#   'gender': 1,
#   'id': 1262,
#   'job': 'Casting',
#   'name': 'Mali Finn'},
#  {'credit_id': '5544ee3b925141499f0008fc',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 1729,
#   'job': 'Original Music Composer',
#   'name': 'James Horner'},
# ...

# %%
def get_crew(a):
    l=[]
    for i in ast.literal_eval(a):
        for j in i.values():
            if(j=="Director"):
                l.append(i["name"])
    return l

# %%
director=movies["crew"].apply(get_crew)

# %%
movies["crew"]=director

# %%
movies.head(10)
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
# 5                   [Fantasy, Action, Adventure]     559
# 6                            [Animation, Family]   38757
# 7           [Action, Adventure, Science Fiction]   99861
# 8                   [Adventure, Fantasy, Family]     767
# 9                   [Action, Adventure, Fantasy]  209112
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
# ...

# %%
movies["overview"] = movies["overview"].apply(lambda x : x.split())

# %%
movies.head(10)
# Out:
#                                           genres      id  \
# 0  [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                   [Adventure, Fantasy, Action]     285
# 2                     [Action, Adventure, Crime]  206647
# 3               [Action, Crime, Drama, Thriller]   49026
# 4           [Action, Adventure, Science Fiction]   49529
# 5                   [Fantasy, Action, Adventure]     559
# 6                            [Animation, Family]   38757
# 7           [Action, Adventure, Science Fiction]   99861
# 8                   [Adventure, Fantasy, Family]     767
# 9                   [Action, Adventure, Fantasy]  209112
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
# ...

# %%
movies["genres"]=movies["genres"].apply(lambda x:[i.replace(" ","") for i in x])
movies["keywords"]=movies["keywords"].apply(lambda x:[i.replace(" ","") for i in x])
movies["overview"]=movies["overview"].apply(lambda x:[i.replace(" ","") for i in x])
movies["cast"]=movies["cast"].apply(lambda x:[i.replace(" ","") for i in x])
movies["crew"]=movies["crew"].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head(1)
# Out:
#                                          genres     id  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]  19995
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
#
#                                             overview   title  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  Avatar
#
#                                             cast            crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]  [JamesCameron]

# %%
movies["tags"]=movies["genres"] + movies["keywords"] + movies["overview"] + movies["cast"] + movies["crew"]

# %%
movies.head(1)
# Out:
#                                          genres     id  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]  19995
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
#
#                                             overview   title  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...  Avatar
#
#                                             cast            crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]  [JamesCameron]
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, c...

# %%
movies = movies[["id","title","tags"]]

# %%
movies.head(10)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
# 5     559                              Spider-Man 3
# 6   38757                                   Tangled
# 7   99861                   Avengers: Age of Ultron
# 8     767    Harry Potter and the Half-Blood Prince
# 9  209112        Batman v Superman: Dawn of Justice
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, c...
# 1  [Adventure, Fantasy, Action, ocean, drugabuse,...
# 2  [Action, Adventure, Crime, spy, basedonnovel, ...
# 3  [Action, Crime, Drama, Thriller, dccomics, cri...
# 4  [Action, Adventure, ScienceFiction, basedonnov...
# 5  [Fantasy, Action, Adventure, dualidentity, amn...
# ...

# %%
movies["tags"] = movies["tags"].apply(lambda x : " ".join(x))

# %%
movies.head(10)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
# 5     559                              Spider-Man 3
# 6   38757                                   Tangled
# 7   99861                   Avengers: Age of Ultron
# 8     767    Harry Potter and the Half-Blood Prince
# 9  209112        Batman v Superman: Dawn of Justice
#
#                                                 tags
# 0  Action Adventure Fantasy ScienceFiction cultur...
# 1  Adventure Fantasy Action ocean drugabuse exoti...
# 2  Action Adventure Crime spy basedonnovel secret...
# 3  Action Crime Drama Thriller dccomics crimefigh...
# 4  Action Adventure ScienceFiction basedonnovel m...
# 5  Fantasy Action Adventure dualidentity amnesia ...
# ...

# %%
movies["tags"] = movies["tags"].apply(lambda x : x.lower())

# %%
movies.head(10)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
# 5     559                              Spider-Man 3
# 6   38757                                   Tangled
# 7   99861                   Avengers: Age of Ultron
# 8     767    Harry Potter and the Half-Blood Prince
# 9  209112        Batman v Superman: Dawn of Justice
#
#                                                 tags
# 0  action adventure fantasy sciencefiction cultur...
# 1  adventure fantasy action ocean drugabuse exoti...
# 2  action adventure crime spy basedonnovel secret...
# 3  action crime drama thriller dccomics crimefigh...
# 4  action adventure sciencefiction basedonnovel m...
# 5  fantasy action adventure dualidentity amnesia ...
# ...

# %%
movies.shape
# Out:
# (4806, 3)

# %%
#convert the tages into vectors then based on the distance we recommand the movies
#some of the words are repeating different types like actor,actors so we convert the text to vector these two word are contributed in seperately to avoid these we are using the stem technique to convert actor and actors into same common words like actor
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
ps.stem("actors")
# Out:
# 'actor'

# %%
def get_common(text):
    final=[]
    for i in text.split():
        final.append(ps.stem(i))
        
    return " ".join(final)

# %%
movies["tags"] = movies["tags"].apply(get_common)

# %%
movies.head(10)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
# 5     559                              Spider-Man 3
# 6   38757                                   Tangled
# 7   99861                   Avengers: Age of Ultron
# 8     767    Harry Potter and the Half-Blood Prince
# 9  209112        Batman v Superman: Dawn of Justice
#
#                                                 tags
# 0  action adventur fantasi sciencefict culturecla...
# 1  adventur fantasi action ocean drugabus exotici...
# 2  action adventur crime spi basedonnovel secreta...
# 3  action crime drama thriller dccomic crimefight...
# 4  action adventur sciencefict basedonnovel mar m...
# 5  fantasi action adventur dualident amnesia sand...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=5000,stop_words="english")

# %%
vectors=cv.fit_transform(movies["tags"]).toarray()

# %%
cv.get_feature_names()
# Out:
# ['000',
#  '007',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '17th',
#  '18',
#  '18th',
#  '18thcenturi',
#  '19',
#  '1910',
#  '1920',
#  '1930',
#  '1940',
#  '1944',
#  '1950',
#  '1950s',
#  '1960',
#  '1960s',
#  '1970',
#  '1970s',
#  '1971',
#  '1974',
#  '1976',
#  '1980',
#  '1985',
#  '1990',
#  '1999',
#  '19th',
#  '19thcenturi',
#  '20',
#  '200',
#  '2003',
#  '2009',
#  '20th',
#  '21st',
#  '23',
#  '24',
#  '25',
#  '30',
#  '300',
#  '3d',
#  '40',
#  '50',
#  '500',
#  '60',
#  '70',
#  '80',
#  'aaron',
#  'aaroneckhart',
#  'abandon',
#  'abduct',
#  'abigailbreslin',
#  'abil',
#  'abl',
#  'aboard',
#  'abov',
#  'abus',
#  'academ',
#  'academi',
#  'accept',
#  'access',
#  'accid',
#  'accident',
#  'acclaim',
#  'accompani',
#  'accomplish',
#  'account',
#  'accus',
#  'ace',
#  'achiev',
#  'acquaint',
#  'act',
#  'action',
#  'actionhero',
#  'activ',
#  'activist',
#  'activities',
#  'actor',
#  'actress',
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
cs = cosine_similarity(vectors)
ls=pd.DataFrame(cs)

# %%
cs[0]
# Out:
# array([1.        , 0.08346223, 0.0860309 , ..., 0.04499213, 0.        ,
#        0.        ])

# %%
def recommand(movie):
    mov_index = movies[movies["title"]==movie].index[0]
    movie_list = sorted(enumerate(cs[movies[movies["title"]==movie].index[0]]),reverse=True,key=lambda x:x[1])[:6]
    for i in movie_list:
        print(movies["title"].iloc[i[0]])

# %%
recommand("Harry Potter and the Half-Blood Prince")
# Out:
# Harry Potter and the Half-Blood Prince
# Harry Potter and the Order of the Phoenix
# Harry Potter and the Goblet of Fire
# Harry Potter and the Chamber of Secrets
# Harry Potter and the Philosopher's Stone
# Harry Potter and the Prisoner of Azkaban

# %%
import pickle

# %%
pickle.dump(movies,open("movie_list.pkl","wb"))

# %%
pickle.dump(ls,open("similarity.pkl","wb"))

# %%
movies
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     action adventur fantasi sciencefict culturecla...
# 1     adventur fantasi action ocean drugabus exotici...
# 2     action adventur crime spi basedonnovel secreta...
# 3     action crime drama thriller dccomic crimefight...
# ...
